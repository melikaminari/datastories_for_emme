# %% [markdown]
# <a href="https://colab.research.google.com/github/melikaminari/datastories_for_emme/blob/main/%CE%91%CE%BD%CF%84%CE%AF%CE%B3%CF%81%CE%B1%CF%86%CE%BF_Homework_for_lesson6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Όπως είδαμε στο μάθημα (στο notebook: https://github.com/datajour-gr/DataJournalism/blob/main/Bachelor%20Lessons%202023/Lesson%206/Classwork6_Scraping_BBC.ipynb), ο κώδικας για να φέρουμε τον τίτλο, το url και την περίληψη όλων των άρθρων από μια σελίδα του bbc, είναι ο εξής:

# %%
# εισάγουμε τις βιβλιοθήκες
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# κατεβάζουμε τη σελίδα που θέλουμε
response = requests.get('http://www.bbc.co.uk/news')
doc = BeautifulSoup(response.text, 'html.parser')

# %%
# Ξεκινάμε με μια άδεια λίστα
stories_list = []
stories = doc.find_all('div', { 'class': 'gs-c-promo' })
for story in stories:
    # Φτιάχνουμε ένα λεξικό χωρίς τίποτα
    story_dict = {}
    headline = story.find('h3')
    if headline:
        story_dict['headline'] = headline.text
    link = story.find('a')
    if link:
        story_dict['url'] = link['href']
    summary = story.find('p')
    if summary:
        story_dict['summary'] = summary.text
    # Προσθέτουμε το λεξικό στη λίστα 
    stories_list.append(story_dict)
    
# Δημιουργούμε dataframe από τη λίστα με τα dictionaries
df = pd.DataFrame(stories_list)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Μετατρέπουμε το dataframe σε CSV και το αποθηκεύουμε στο drive.
# Xρησιμοποιούμε το index=False, για να μην αποθηκευτεί ο αύξοντας αριθμός των rows.
df = pd.DataFrame(stories_list)
df.to_csv("/content/drive/MyDrive/bbc.csv", index=False)

# %%
df
# Out:
#                                              headline  \
# 0   Bakhmut not occupied by Russia, says defiant Z...
# 1   Watch: Japan riot police pin G7 protesters to ...
# 2   Sudan army fights to keep key airbase - residents
# 3   Watch what school in an empty shopping mall lo...
# 4   Kalashnikov attack on car kills three in Marse...
# 5      Guitar smashed by Kurt Cobain fetches $600,000
# 6     Premier League: Champions Man City host Chelsea
# 7   Jennifer Lawrence’s secret filming gives Afgha...
# 8   At least twelve killed in El Salvador stadium ...
# 9                   Novelist Martin Amis dies aged 73
# 10  ICC 'undeterred' by arrest warrant for top pro...
# 11                  Novelist Martin Amis dies aged 73
# 12  ICC 'undeterred' by arrest warrant for top pro...
# 13  Man City win third successive Premier League t...
# 14       Greece recovers hundreds of stolen artefacts
# 15  Man arrested after damage done to statue at BB...
# 16      You think you know Satanists? Maybe you don't
# 17                                  BBC World News TV
# 18                            BBC World Service Radio
# 19           Could 'magic dust' help cool the planet?
# 20  Watch: Officer clings to speeding car in wild ...
# 21  Montana TikTok creators shrug off state's ban ...
# 22                          Americast: Murder Capital
# 23  Why G7 has eight more seats at the table this ...
# 24  Crucial questions as US supports fighter jets ...
# 25     Serbians hand in guns after two mass shootings
# 26  What a coffee ad reveals about transphobia in ...
# 27           US inches to default with no backup plan
# 28             Kidnapping and debt: A Nigerian legacy
# 29   Why the world cares who wins Turkey's presidency
# 30     Inside the routine at Elizabeth Holmes' prison
# 31                          What comes after the ISS?
# 32            Why workers feel they never make enough
# 33            Southeast Asia's ubiquitous curry puffs
# 34                'DiCaprio and De Niro are a thrill'
# 35              Does your diet affect your fertility?
# 36            Why it's 'imperative' to start using AI
# 37                A 5,000-year-old craft under threat
#
#                                                   url  \
# 0                         /news/world-europe-65662563
# 1                           /news/world-asia-65663384
# 2                         /news/world-africa-65662939
# 3                      /news/world-us-canada-65551793
# 4                         /news/world-europe-65664329
# 5                      /news/world-us-canada-65664330
# 6                       /sport/live/football/65448263
# 7                                /news/world-65624203
# 8                  /news/world-latin-america-65662194
# 9                   /news/entertainment-arts-65660768
# 10                        /news/world-europe-65661251
# 11                  /news/entertainment-arts-65660768
# 12                        /news/world-europe-65661251
# 13                           /sport/football/65613744
# 14                        /news/world-europe-65657620
# 15                                  /news/uk-65655332
# 16                     /news/world-us-canada-65549975
# 17                           /news/world_radio_and_tv
# 18                /sounds/play/live:bbc_world_service
# 19                 /news/science-environment-65648361
# 20                     /news/world-us-canada-65640384
# 21                     /news/world-us-canada-65642954
# 22                             https://bbc.in/3LiJlFN
# 23                          /news/world-asia-65630650
# 24                        /news/world-europe-65656356
# 25                        /news/world-europe-65597622
# 26                    /news/world-asia-india-65644038
# 27                            /news/business-65627854
# 28                        /news/world-africa-65637553
# 29                        /news/world-europe-65647483
# 30                     /news/world-us-canada-65625526
# 31  https://www.bbc.com/future/article/20230512-wh...
# 32  https://www.bbc.com/worklife/article/20230512-...
# 33  https://www.bbc.com/travel/article/20230519-so...
# 34  https://www.bbc.com/culture/article/20230521-k...
# 35  https://www.bbc.com/future/article/20230510-ca...
# 36  https://www.bbc.com/worklife/article/20230515-...
# 37  https://www.bbc.com/travel/article/20230518-th...
#
#                                               summary
# 0   Russia's Wagner group claims to have taken ful...
# 1   Violence broke out in Hiroshima as riot police...
# 2   Paramilitaries are trying to cross the River N...
# 3   How one US school found a clever solution when...
# 4   The killings near a nightclub come amid a spik...
# 5   The black Stratocaster destroyed by Nirvana's ...
# 6   Follow live text updates as Manchester City ho...
# 7   Oscar-winning actress tells BBC about working ...
# 8   The disaster happened during a clash between t...
# 9   The influential author of Money and London Fie...
# 10  Russia placed ICC boss Karim Khan on a wanted ...
# 11  The influential author of Money and London Fie...
# 12  Russia placed ICC boss Karim Khan on a wanted ...
# 13  Manchester City are crowned Premier League cha...
# 14  Among the 351 objects being repatriated is a 2...
# 15  Police spent much of Saturday trying to get th...
# 16                                                NaN
# 17  The latest global news, sport, weather and doc...
# 18                      Stories from around the world
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN

# %% [markdown]
# ## **Extra tips**

# %% [markdown]
# ### **Διόρθωση των ελλειπών urls**

# %% [markdown]
# Όπως βλέπουμε στο df, κάποια urls δεν είναι ολόκληρα, ενώ κάποια άλλα είναι. Παρατηρούμε ότι το κομμάτι που λείπει είναι το main url, δηλαδή το ```"https://www.bbc.com"```

# %% [markdown]
# Μπορούμε να διορθώσουμε τα ελλειπή urls με τον παρακάτω κώδικα:

# %%
df['url_new'] = df.apply(lambda x: x['url'] if x['url'].startswith("http") else "https://www.bbc.com" + x['url'], axis=1)

# %% [markdown]
# Ο παραπάνω κώδικας δημιουργεί μια νέα στήλη ('url_new') και σε κάθε row βάζει την τιμή του κελιού από τη στήλη 'url' αν η τιμή αρχίζει με 'http', αλλιώς προσθέτει στην αρχή της τιμής του κελιού 'url' το "http://www.bbc.com".

# %%
df
# Out:
#                                              headline  \
# 0   Bakhmut not occupied by Russia, says defiant Z...
# 1   Watch: Japan riot police pin G7 protesters to ...
# 2   Sudan army fights to keep key airbase - residents
# 3   Watch what school in an empty shopping mall lo...
# 4   Kalashnikov attack on car kills three in Marse...
# 5      Guitar smashed by Kurt Cobain fetches $600,000
# 6     Premier League: Champions Man City host Chelsea
# 7   Jennifer Lawrence’s secret filming gives Afgha...
# 8   At least twelve killed in El Salvador stadium ...
# 9                   Novelist Martin Amis dies aged 73
# 10  ICC 'undeterred' by arrest warrant for top pro...
# 11                  Novelist Martin Amis dies aged 73
# 12  ICC 'undeterred' by arrest warrant for top pro...
# 13  Man City win third successive Premier League t...
# 14       Greece recovers hundreds of stolen artefacts
# 15  Man arrested after damage done to statue at BB...
# 16      You think you know Satanists? Maybe you don't
# 17                                  BBC World News TV
# 18                            BBC World Service Radio
# 19           Could 'magic dust' help cool the planet?
# 20  Watch: Officer clings to speeding car in wild ...
# 21  Montana TikTok creators shrug off state's ban ...
# 22                          Americast: Murder Capital
# 23  Why G7 has eight more seats at the table this ...
# 24  Crucial questions as US supports fighter jets ...
# 25     Serbians hand in guns after two mass shootings
# 26  What a coffee ad reveals about transphobia in ...
# 27           US inches to default with no backup plan
# 28             Kidnapping and debt: A Nigerian legacy
# 29   Why the world cares who wins Turkey's presidency
# 30     Inside the routine at Elizabeth Holmes' prison
# 31                          What comes after the ISS?
# 32            Why workers feel they never make enough
# 33            Southeast Asia's ubiquitous curry puffs
# 34                'DiCaprio and De Niro are a thrill'
# 35              Does your diet affect your fertility?
# 36            Why it's 'imperative' to start using AI
# 37                A 5,000-year-old craft under threat
#
#                                                   url  \
# 0                         /news/world-europe-65662563
# 1                           /news/world-asia-65663384
# 2                         /news/world-africa-65662939
# 3                      /news/world-us-canada-65551793
# 4                         /news/world-europe-65664329
# 5                      /news/world-us-canada-65664330
# 6                       /sport/live/football/65448263
# 7                                /news/world-65624203
# 8                  /news/world-latin-america-65662194
# 9                   /news/entertainment-arts-65660768
# 10                        /news/world-europe-65661251
# 11                  /news/entertainment-arts-65660768
# 12                        /news/world-europe-65661251
# 13                           /sport/football/65613744
# 14                        /news/world-europe-65657620
# 15                                  /news/uk-65655332
# 16                     /news/world-us-canada-65549975
# 17                           /news/world_radio_and_tv
# 18                /sounds/play/live:bbc_world_service
# 19                 /news/science-environment-65648361
# 20                     /news/world-us-canada-65640384
# 21                     /news/world-us-canada-65642954
# 22                             https://bbc.in/3LiJlFN
# 23                          /news/world-asia-65630650
# 24                        /news/world-europe-65656356
# 25                        /news/world-europe-65597622
# 26                    /news/world-asia-india-65644038
# 27                            /news/business-65627854
# 28                        /news/world-africa-65637553
# 29                        /news/world-europe-65647483
# 30                     /news/world-us-canada-65625526
# 31  https://www.bbc.com/future/article/20230512-wh...
# 32  https://www.bbc.com/worklife/article/20230512-...
# 33  https://www.bbc.com/travel/article/20230519-so...
# 34  https://www.bbc.com/culture/article/20230521-k...
# 35  https://www.bbc.com/future/article/20230510-ca...
# 36  https://www.bbc.com/worklife/article/20230515-...
# 37  https://www.bbc.com/travel/article/20230518-th...
#
#                                               summary  \
# 0   Russia's Wagner group claims to have taken ful...
# 1   Violence broke out in Hiroshima as riot police...
# 2   Paramilitaries are trying to cross the River N...
# 3   How one US school found a clever solution when...
# 4   The killings near a nightclub come amid a spik...
# 5   The black Stratocaster destroyed by Nirvana's ...
# 6   Follow live text updates as Manchester City ho...
# 7   Oscar-winning actress tells BBC about working ...
# 8   The disaster happened during a clash between t...
# 9   The influential author of Money and London Fie...
# 10  Russia placed ICC boss Karim Khan on a wanted ...
# 11  The influential author of Money and London Fie...
# 12  Russia placed ICC boss Karim Khan on a wanted ...
# 13  Manchester City are crowned Premier League cha...
# 14  Among the 351 objects being repatriated is a 2...
# 15  Police spent much of Saturday trying to get th...
# 16                                                NaN
# 17  The latest global news, sport, weather and doc...
# 18                      Stories from around the world
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
#
#                                               url_new
# 0      https://www.bbc.com/news/world-europe-65662563
# 1        https://www.bbc.com/news/world-asia-65663384
# 2      https://www.bbc.com/news/world-africa-65662939
# 3   https://www.bbc.com/news/world-us-canada-65551793
# 4      https://www.bbc.com/news/world-europe-65664329
# 5   https://www.bbc.com/news/world-us-canada-65664330
# 6    https://www.bbc.com/sport/live/football/65448263
# 7             https://www.bbc.com/news/world-65624203
# 8   https://www.bbc.com/news/world-latin-america-6...
# 9   https://www.bbc.com/news/entertainment-arts-65...
# 10     https://www.bbc.com/news/world-europe-65661251
# 11  https://www.bbc.com/news/entertainment-arts-65...
# 12     https://www.bbc.com/news/world-europe-65661251
# 13        https://www.bbc.com/sport/football/65613744
# 14     https://www.bbc.com/news/world-europe-65657620
# 15               https://www.bbc.com/news/uk-65655332
# 16  https://www.bbc.com/news/world-us-canada-65549975
# 17        https://www.bbc.com/news/world_radio_and_tv
# 18  https://www.bbc.com/sounds/play/live:bbc_world...
# 19  https://www.bbc.com/news/science-environment-6...
# 20  https://www.bbc.com/news/world-us-canada-65640384
# 21  https://www.bbc.com/news/world-us-canada-65642954
# 22                             https://bbc.in/3LiJlFN
# 23       https://www.bbc.com/news/world-asia-65630650
# 24     https://www.bbc.com/news/world-europe-65656356
# 25     https://www.bbc.com/news/world-europe-65597622
# 26  https://www.bbc.com/news/world-asia-india-6564...
# 27         https://www.bbc.com/news/business-65627854
# 28     https://www.bbc.com/news/world-africa-65637553
# 29     https://www.bbc.com/news/world-europe-65647483
# 30  https://www.bbc.com/news/world-us-canada-65625526
# 31  https://www.bbc.com/future/article/20230512-wh...
# 32  https://www.bbc.com/worklife/article/20230512-...
# 33  https://www.bbc.com/travel/article/20230519-so...
# 34  https://www.bbc.com/culture/article/20230521-k...
# 35  https://www.bbc.com/future/article/20230510-ca...
# 36  https://www.bbc.com/worklife/article/20230515-...
# 37  https://www.bbc.com/travel/article/20230518-th...

# %% [markdown]
# # **Άσκηση**

# %% [markdown]
# Κάνετε όποια/όποιες από τις παρακάτω ασκήσεις θέλετε:
#
# **1. Βαθμός δυσκολίας: πολύ εύκολο**
#
# Προσαρμόστε κατάλληλα τον κώδικα του notebook https://github.com/datajour-gr/DataJournalism/blob/main/Bachelor%20Lessons%202023/Lesson%206/Scraping%20with%20newspaper3k%20module.ipynb (με το module newspaper3k) για να μαζέψετε δεδομένα από τα άρθρα της κατηγορίας latest του news247 (https://www.news247.gr/latest/) και της efsyn.
#
# **2. Βαθμός δυσκολίας: εύκολο**
#
# Το ίδιο με παραπάνω (1) αλλά μαζέψτε δεδομένα από 3 σελίδες της κατηγορίας latest.
#
# Hint: χρησιμοποιήστε το /?page=
#
# **3. Βαθμός δυσκολίας: μέτριο**
#
# Προσαρμόστε κατάλληλα τον κώδικα που έχουμε χρησιμοποιήσει με το requests και το BeautifulSoup για να μαζέψετε δεδομένα άρθρων από την κατηγορία των τελευταίων ειδήσεων του news247 (https://www.news247.gr/latest/)
#
# Στη συνέχεια φτιάξτε μια for loop για να μαζέψετε πληροφορίες άρθρων από περισσότερες από μία σελίδες της ίδιας κατηγορίας (χρησιμοποιήστε το /?page=)
#
# **4a. Βαθμός δυσκολίας: προχωρημένο**
#
# Με τη χρήση του requests και του BeautifulSoup:
# 1. Μαζέψτε (μόνο) τα urls των άρθρων της Κυριακής 14/5/2023 από την κατηγορία των τελευταίων ειδήσεων του news247 (https://www.news247.gr/latest/?page=) και αποθηκεύστε τα σε μία λίστα.
# 2. Μαζέψτε για κάθε άρθρο στη λίστα τον τίτλο, το url του, την ημερομηνία, τον συντάκτη, την κατηγορία (section) και το κείμενο του άρθρου.
#
# **4b. Βαθμός δυσκολίας: προχωρημένο**
#
# Εναλλακτικά, μπορείτε να μαζέψετε τις πληροφορίες από reviews των χρηστών του trip advisor (π.χ. https://www.tripadvisor.com/AttractionProductReview-g189400-d11476899-Skip_the_Line_Acropolis_of_Athens_Afternoon_Walking_Tour-Athens_Attica.html).
#
# Μαζέψτε το rating (τα bubbles), τον τίτλο του review (π.χ. Highly recommend tour + museum), το πότε γράφτηκε το review και το text του review.
#
# **4c. Βαθμός δυσκολίας: προχωρημένο**
#
# Μπορείτε να μαζέψετε δεδομένα από σχόλια σε ένα video στο youtube (όνομα χρήστη, ημερομηνία, κείμενο).

# %%
# !pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (8.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.2)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.27.1)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 8.9 MB/s eta 0:00:00
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-3.4.4-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 11.6 MB/s eta 0:00:00
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 90.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.12.0)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13541 sha256=072d1a3a7dc4ebdae2bb2e61175ce26b237db711cc3d3fd7e6d1cbe1e23e312a
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=2e484ab85b8fee117ecfa8a9b757d513cc4234662acce43c736b33733c665fcc
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398382 sha256=d008f8a9d7978abdeeda5cb910d476e736d22ceff6f756fdf0238fd7d03a9ae1
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=65ae7080f89d7012351179fe8362e5c5cfe6fcaad99ef6fe38f475b6dd8cc79d
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.10 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-3.4.4

# %%
import newspaper

# %%
site_url="https://www.news247.gr/latest/"

# %%
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feeds

# %%
# get list of article URLs
urlsL = site.article_urls()

print(len(urlsL))
# print the first 10 articles urls
urlsL[:10]
# Out:
# 43
# ['https://www.news247.gr/live-blog/ekloges-2023-live.10044986.html',
#  'https://www.news247.gr/ekloges/ekloges-2023-sto-48-76-i-symmetochi-stis-kalpes-eos-tis-16-30.10051103.html',
#  'https://www.news247.gr/media/pethane-o-dimosiografos-christos-matis.10051218.html',
#  'https://www.news247.gr/koinonia/ekloges-2023-stis-kalpes-me-nyfiko-kai-kostoymi-psifisan-amesos-meta-ton-gamo-toys.10051088.html',
#  'https://www.news247.gr/ekloges/ekloges-2023-kriti-psifoforoi-kleidothikan-mesa-sto-eklogiko-kentro.10051092.html',
#  'https://www.oneman.gr/life/pos-ezisan-oi-touristes-tis-ekloges-stin-ellada/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos1',
#  'https://www.oneman.gr/life/epiki-giagia-stis-serres-afti-elpizo-na-einai-i-teleftaia-fora-pou-psifizo/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos2',
#  'https://www.oneman.gr/politiki/afto-einai-to-erotimatologio-tou-exit-poll/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos3',
#  'https://www.ladylike.gr/wellness/filliko-oxi-oi-korifaies-trofes-gia-tin-aparaititi-vitamini-b9/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos1',
#  'https://www.ladylike.gr/life/pinterest-6-prototipoi-tropoi-na-antikatastiseis-tis-glastres-me-kalathia/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos2']

# %%
# import libraries
from newspaper import Article
import pandas as pd
import numpy as np

# %%
article = Article(urlsL[0])
article.download()
article.parse()

# %%
# define site url
site_url = "https://www.news247.gr/latest/"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feed

# %%
# define site url
site_url = "https://www.efsyn.gr/news?page=1"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feed

# %%
# define site url
site_url = "https://www.enikos.gr/#/?page=1:3"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.enikos.gr/feeds

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
import requests
site_url="https://www.news247.gr/latest/"
result=requests.get(site_url).text
print(result)
# Out:
# <!DOCTYPE html>
#         <html lang="el">
#             <!-- D -->
#             <head>
#
#                 <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#                 <meta name="viewport" content="width=device-width, minimum-scale=.5">
#
#                 <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png?v=1.23.4568">
#                 <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png?v=1.23.4568">
#                 <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png?v=1.23.4568">
#
#                 <link rel="manifest" href="/site.webmanifest">
#                 <link rel="mask-icon" href="/safari-pinned-tab.svg?v=2.23.4567" >
#                 <meta name="apple-mobile-web-app-title" content="News 24/7">
#                 <meta name="application-name" content="News 24/7">
#                 <meta name="msapplication-TileColor" content="#ffffff">
#                 <meta name="msapplication-TileImage" content="/ms-icon-144x144.png?v=1.23.4568">
#                 <meta name="theme-color" content="#ffffff">
#
#                 <!-- Critical CSS -->
#                 <style>
#     body,html{background:#fff;width:100%;height:auto;margin:0;padding:0;font-family:Open Sans,sans-serif;font-weight:400;font-size:10px}a{color:#000}.container{width:1000px;padding:0 10px}.container_ad{width:auto;padding:0}.container .row{margin:0}body>.container{background-color:#fff}[class*=col-]{padding-left:10px;padding-right:10px}.col-md-8,.col-md-9{padding:0}.col-md-9{width:69.699%}.col-md-8{width:67.347%}.col-md-3,.col-md-4{padding:0}.col-md-4{width:32.653%}.col-md-3{width:30.301%}*{outline:0}.sidebar{position:relative;margin-right:0;margin-left:20px;height:100%}.bold{font-weight:700}body.ece_frontpage .with-sidebar .sidebar .teaser:first-child .teaser__content:first-child .teaser__article:first-child .article__title{margin-top:0}img.lazy:not([src]){visibility:hidden}@font-face{font-family:Open Sans;font-weight:700;font-display:swap;src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-bold.eot);src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-bold.eot?#iefix) format("embedded-opentype"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-bold.woff2) format("woff2"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-bold.woff) format("woff"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-bold.ttf) format("truetype")}@font-face{font-family:Open Sans;font-weight:800;font-display:swap;src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-extrabold.eot);src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-extrabold.eot?#iefix) format("embedded-opentype"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-extrabold.woff2) format("woff2"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-extrabold.woff) format("woff"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-extrabold.ttf) format("truetype")}@font-face{font-family:Open Sans;font-display:swap;src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-italic.eot);src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-italic.eot?#iefix) format("embedded-opentype"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-italic.woff2) format("woff2"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-italic.woff) format("woff"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-italic.ttf) format("truetype")}@font-face{font-family:Open Sans;font-weight:600;font-display:swap;src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-semibold.eot);src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-semibold.eot?#iefix) format("embedded-opentype"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-semibold.woff2) format("woff2"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-semibold.woff) format("woff"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-semibold.ttf) format("truetype")}@font-face{font-family:Open Sans;font-weight:300;font-display:swap;src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-light.eot);src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-light.eot?#iefix) format("embedded-opentype"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-light.woff2) format("woff2"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-light.woff) format("woff"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-light.ttf) format("truetype")}@font-face{font-family:Open Sans;font-weight:400;font-display:swap;src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-regular.eot);src:url(https://www.news247.gr/resources/b609df7/fonts/opensans-regular.eot?#iefix) format("embedded-opentype"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-regular.woff2) format("woff2"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-regular.woff) format("woff"),url(https://www.news247.gr/resources/b609df7/fonts/opensans-regular.ttf) format("truetype")}@font-face{font-family:Roboto Slab;font-weight:300;font-display:swap;src:url(h ...
#
#     /* Jira: https://24mediagr.atlassian.net/browse/SUP-539 */
#
#     [id*="300x250"]:not([id*='google_ads_iframe_']),
#     [id*="div-gpt-ad-"]:not([id*='google_ads_iframe_']),
#     [id*="ros-article-end"]:not([id*='google_ads_iframe_']),
#     .mobile [id*="ros-inline"]:not([id*='google_ads_iframe_']),
#     .mobile [id^="sunday_"]:not([id*='google_ads_iframe_']){
#         /* NOTE: check is needed ->   width: 100%; */
#         /* min-height: 250px; */
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#         background-image: url("data:image/svg+xml;utf8,<svg width='300' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='300' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-15%'>Advertisement</text></svg>");
#     }
#
#     /* this rule fixes inlineA top space when displays video or ads form adman/phaistos */
#     [id*=ros-inlineA] [id*=google_ads_iframe_]{
#         line-height: 0;
#     }
#
#     /* fixes alignment issue for creatives that is displayed by ocm with tag ins in ros-inline slots */
#     [id^="ros-"]:not([id*='google_ads_iframe_']){
#         text-align: center;
#     }
#
#     /* this rule is only for mobile inlineA that displays video ads form adman/phaistos */
#     .mobile [id*=ros-inlineA]:not([id*=google_ads_iframe_]){
#         background-image: url("data:image/svg+xml;utf8,<svg width='100%' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='100%' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-50px'>Advertisement</text></svg>");
#     }
#
#     .mobile.news:not(.sunday-edition) [id^=ros-inline]{
#         background-size: 300px 250px;
#     }
#
#     @media (min-width: 361px) {
#         [id*="sunday_hp_300x250"]:not([id*='google_ads_iframe_']){
#             max-width: 300px;
#         }
#     }
#
#     /* this is only for tablet sunday edition homepage  */
#     @media (min-width:768px) and (max-width:1024px){
#         body:not(.mobile) #sunday_hp_300x250b{
#             width:100%;
#             max-width:unset;
#             background-image: url("data:image/svg+xml;utf8,<svg width='728' height='90' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='728' height='90' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-5%'>Advertisement</text></svg>");
#         }
#     }
#
#     [id$="_billboard"]:not([id*='google_ads_iframe_']),
#     [id*="970x250"]:not([id*='google_ads_iframe_']){
#         width: 100%;
#         min-height: 250px;
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#         background-image: url("data:image/svg+xml;utf8,<svg width='970' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='970' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-5%'>Advertisement</text></svg>");
#     }
#
#     /* div-gpt-ad-slot_1_2 */
#
#     [id*="div-gpt-ad-slot"]:not([id*='google_ads_iframe_']){
#         width: 100%;
#         min-height: 280px;
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#         background-image: url("data:image/svg+xml;utf8,<svg width='660' height='280' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='660' height='280' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-5%'>Advertisement</text></svg>");
#     }
#
#     /* ros-inline */
#
#     [id^="sunday_article_inline"]:not([id*='google_ads_iframe_']){
#         width: 100%;
#         min-height: 400px;
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#         background-image: url("data:image/svg+xml;utf8,<svg width='660' height='400' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='660' height='400' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-5%'>Advertisement</text></svg>");
#     }
#
#     /* ros-inline for default articles */
#
#     body:not(.mobile) [id*="ros-inline"]:not([id*='google_ads_iframe_']){
#         width: 100%;
#         min-height: 400px;
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#         background-image: url("data:image/svg+xml;utf8,<svg width='300' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='300' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-15%'>Advertisement</text></svg>");
#     }
#
#     /* sunday_article_inline_b */
#
#     [id="sunday_article_inline_b"]:not([id*='google_ads_iframe_']){
#         width: 100%;
#         min-height: 600px;
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#         background-image: url("data:image/svg+xml;utf8,<svg width='660' height='600' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='660' height='600' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-5%'>Advertisement</text></svg>");
#     }
#
#     /* sunday_article_end */
#
#     [id="sunday_article_end"]:not([id*='google_ads_iframe_']){
#         min-height: 250px;
#         background-repeat: no-repeat;
#         background-size: initial;
#         background-position:center top;
#     //background-image: url("data:image/svg+xml;utf8,<svg width='970' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='970' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-5%'>Advertisement</text></svg>");
#         background-image: url("data:image/svg+xml;utf8,<svg width='300' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='300' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-15%'>Advertisement</text></svg>");
#     }
#
#     /**
#         reset for mobile
#     **********************/
#
#     .mobile div:has(> #hp-300x250a),
#     .mobile div:has(> #hp-300x250b),
#     .mobile div:has(> #hp-300x250c),
#     .mobile div:has(> #hp-300x250d),
#     .mobile div:has(> #ros-300x250b),
#     .mobile div:has(> #ros-inlineA),
#     .mobile div:has(> #ros-inlineB),
#     .mobile div:has(> #sunday_article_inline_a),
#     .mobile div:has(> #sunday_article_inline_b){
#         position:relative;
#         min-height: 600px;
#     }
#
#     body.ece_frontpage.mobile [id*="300x250"]:not([id*='google_ads_iframe_']){
#         background-position-y: 30px
#     }
#
#     body.ece_frontpage.mobile #main>.container>.ad-widget>div[id*=hp-] {
#         padding: 30px 0;
#         position: sticky;
#     }
#
#     .mobile #hp-300x250a>:not([id^=adman-]):not([class^=adman]),
#     .mobile div#hp-300x250b>:not([id^=adman-]):not([class^=adman]),
#     .mobile div#hp-300x250c>:not([id^=adman-]):not([class^=adman]),
#     .mobile div#hp-300x250d>:not([id^=adman-]):not([class^=adman]),
#     .mobile div#ros-300x250b>:not([id^=adman-]):not([class^=adman]),
#     .mobile div#ros-inlineB>:not([id^=adman-]):not([class^=adman]),
#     .mobile div#ros-inlineA>:not([id^=adman-]):not([class^=adman]),
#     .mobile [id^="sunday_article_inline_"]>:not([id^=adman-]):not([class^=adman]){
#         position:relative;
#         top:auto;
#     }
#
#     .mobile #hp-300x250a,
#     .mobile div#hp-300x250b,
#     .mobile div#hp-300x250c,
#     .mobile div#hp-300x250d,
#     .mobile div#ros-300x250b,
#     .mobile div#ros-inlineA,
#     .mobile div#ros-inlineB,
#     .mobile [id^="sunday_article_inline_"]:not([id*='google_ads_iframe_']){
#         min-height: 250px!important;
#         position:sticky;
#         top:85px;
#         margin:0 auto;
#         align-self: flex-start;
#     }
#
#     /* mobile article specific */
#     .mobile .article-body__storyContent [id*="ros-inline"]:not([id*='google_ads_iframe_']){
#         min-height:unset;
#     }
#
#     /* fixes align vertical */
#     body:not(.mobile) [id^=hp]:not([id*=google_ads_iframe_]),
#     body:not(.mobile) [id^=ros]:not([id*=google_ads_iframe_]),
#     body:not(.mobile) [id^=div-gpt-ad-]:not([id*=google_ads_iframe_]),
#     body:not(.mobile) [id^=sunday_]:not([id*=google_ads_iframe_]){
#         display:flex;
#         justify-content: center;
#         flex-direction: column;
#     }
#
#     body.mobile [id^=sunday_]:not([id*=google_ads_iframe_]){
#         width: auto;
#     }
#
#     /* fix for inline
#        ros-inlineA in default article template desktop,
#        sunday_article_inline_a & sunday_article_inline_b in sunday edition article template desktop
#     */
#     body:not(.mobile) .stickiness--parent{
#         min-height: 400px;
#     }
#
#     body:not(.mobile) .border-bottom__1-gray{
#         border-bottom: 1px solid rgb(221, 221, 221);
#     }
#
#     body:not(.mobile) .stickiness--parent #ros-inlineA{
#         min-height: 250px;
#         height: auto;
#         position: sticky;
#         top: 85px;
#     }
#
#     body:not(.mobile) .stickiness--parent #sunday_article_inline_a,
#     body:not(.mobile) .stickiness--parent #sunday_article_inline_b{
#         min-height: 250px;
#         width: auto;
#         height: fit-content;
#         position: sticky;
#         top: 85px;
#         margin-top:20px;
#         background-image: url("data:image/svg+xml;utf8,<svg width='300' height='250' xmlns='http://www.w3.org/2000/svg'><rect fill='ghostwhite' width='300' height='250' x='0' y='0'/><text font-family='Arial, Helvetica, sans-serif' fill='lightgray' x='50%' y='50%' dx='-15%'>Advertisement</text></svg>");
#     }
#     /* end of fix for inline*/
#
#
# </style>
# <!-- isErrorPage: false -->
#
#                 <script>
#     window.targettingValues = {};
#     window.targettingValues['path'] = "https://www.news247.gr/latest/";
#     window.targettingValues['article'] = "";
#     window.targettingValues['keywords'] = [""];
#     window.targettingValues['category'] = ["ece_frontpage", "latest"];
#     window.targettingValues['type'] = "sec";
#     window.targettingValues['isApp'] = "";
#     window.targettingValues['isAmp'] = "false";
#     window.targettingValues['isMobile'] = "false";
#     window.targettingValues['categoryDisplayName'] = "ειδήσεις";
#     window.targettingValues['tagDisplayName'] = [""];
#     window.targettingValues['isErrorPage'] = "false";
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(window.targettingValues);
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PPWK62G');</script>
# <!-- End Google Tag Manager -->
# <title>Ειδήσεις Τώρα - Ροή Ειδήσεων | News 24/7</title>
# <meta name="description" content="Όλη η ροή ειδήσεων από την Ελλάδα και τον Κόσμο. Τελευταία νέα, Έκτακτη επικαιρότητα, Πολιτική, Οικονομία, Ελλάδα, Κόσμος, Καιρός">
#     <link rel="canonical" href="https://www.news247.gr/latest/" />
#     <script type="application/ld+json">
#         {
#             "@context": "https://schema.org",
#             "@type": "CollectionPage",
#             "@id": "https://www.news247.gr/latest/#section",
#             "name": "Ειδήσεις Τώρα - Ροή Ειδήσεων | News 24/7",
#             "description": "Όλη η ροή ειδήσεων από την Ελλάδα και τον Κόσμο. Τελευταία νέα, Έκτακτη επικαιρότητα, Πολιτική, Οικονομία, Ελλάδα, Κόσμος, Καιρός",
#             "url": "https://www.news247.gr/latest/",
#             "image": "https://www.news247.gr/img/5058/9069244/811000/w620/620/news247_facebook_og_image.png",
#             "thumbnailUrl": "https://www.news247.gr/img/5058/9069244/811000/w620/620/news247_facebook_og_image.png",
#             "keywords": [],
#             "publisher": {
#                 "@type": "Organization",
#                 "@id": "https://www.news247.gr/#organization",
#                 "url": "https://www.news247.gr/",
#                 "name": "News 24/7",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "url": "https://www.news247.gr/resources/b609df7/images/metadata-logo.png"
#                 }
#             },
#             "isPartOf": {
#                 "@type": "WebSite",
#                 "@id": "https://www.news247.gr/#site"
#             }
#         }
#         </script>
#     <meta property="og:type" content="website">
#         <meta property="og:url" content="https://www.news247.gr/latest/">
#         <meta property="og:title" content="Ειδήσεις Τώρα - Ροή Ειδήσεων | News 24/7">
#         <meta property="og:description" content="Όλη η ροή ειδήσεων από την Ελλάδα και τον Κόσμο. Τελευταία νέα, Έκτακτη επικαιρότητα, Πολιτική, Οικονομία, Ελλάδα, Κόσμος, Καιρός">
#             <meta property="og:image" content="https://www.news247.gr/img/7643/9069244/811000/o/1200/1200/news247_facebook_og_image.png">
#     <!-- section -->
#     <meta name="parsely-section" content="Ειδήσεις" />
# <meta property="fb:app_id" content="767480436596774" />
# <meta property="fb:pages" content="91157111480" />
# <meta name="google-site-verification" content="iswD1C1LlZMb7qqV7njz-KZrimCEVl3Br94RPWwWgG8" />
# <!-- Google Tag object cmd-->
# <script>window.googletag = window.googletag || {cmd: []}</script>
# <!-- meta max-image-preview:large - Google : This applies to all forms of search results (such as Google web search, Google Images, Discover, Assistant) -->
# <meta name="robots" content="max-image-preview:large"><style>
# .ros_title.noAdTiltle:before{
# display:none!important;
# }
# .ros_title.noAdTiltle .widget__header.ad_label{
# display:none!important;
# }
# .ad-widget_300x250{
# display:block!important;
# }
# #ros-300x250b{
# height:auto!important;
# }
# </style><script src="https://www.news247.gr/resources/b609df7/scripts/vendor.js"></script>
#         <link rel="stylesheet" href="https://www.news247.gr/resources/b609df7/styles/vendor.css?v=0.01222">
#         <link rel="stylesheet" href="https://www.news247.gr/resources/b609df7/styles/main_2020.css?redesign=1.02.08.30.03012023122321212">
#         <!-- live-blog Version -->
# <script>
#     const liveBlogVersion = '1.47';
# </script>
#
# <!-- live-blog main video width fix desktop/mobile -->
# <style>
# .article-body__article-head-box + iframe[src *= 'youtube'] {
#     width: 100%;
# }
# /* fix for SUP-506 */
# .teaser--podcast-gray-scale .article__title{
# max-height: 112px;
# }
# </style>
# <style>
#     .special-issue {
#         margin-bottom: 20px;
#     }
#     .col-md-4 .sidebar .top-stories__article {
#         max-width: 300px;
#     }
#     .ekloges2019-map-hp {
#         margin-bottom: 40px;
#         overflow: hidden;
#     }
#     .ekloges2019-map-hp .widget-header {
#         background: #fff;
#         position: relative;
#         z-index: 1;
#         text-align: center;
#     }
#     .ekloges2019-map-hp > iframe {
#         margin-top: -63px;
#         border: none;
#     }
#     body.mobile .ekloges2019-map-hp {
#         padding: 0 10px;
#         margin-bottom: 20px;
#     }
#     body.mobile .ekloges2019-map-hp > iframe {
#         width: 100%;
#         max-height: 750px;
#         border: none;
#     }
#     body.mobile .afieromatiko {
#         margin-bottom: 20px;
#     }
#     @media (min-width: 360px) {
#         body.mobile .ekloges2019-map-hp {
#             padding: 0 20px;
#         }
#     }
# .mobile .teaser_tanzania .teaser__header a:after {
#     font: normal normal 700 49.64px/0 Roboto Slab,sans-serif;
#     position: relative;
#     display: block;
#     color: #000;
#     letter-spacing: -.5px;
#     content: "Senegal";
#     padding-bottom: 36px;
#     margin: 20px -15px 7px 0;
#     text-indent: -2px;
# }
# </style><script>
# /* TEMPORARY FIX for firefox instagram bug
#  * task: TECH-99
# */
#
# setTimeout(function(){
#
# let reg = /((\bnews\b)|(\bstandardTemplate\b))/g;
# let body_classList = document.body.classList.value;
#
# if( body_classList.match(reg)){
#      //console.log("found:", body_classList.match(reg));
#
#      var browser = navigator.userAgent;
#      var iframe = document.querySelectorAll('.instagram-media')[0];
#     if ( browser.indexOf('Firefox') > -1 || browser.indexOf("Mobile") > -1) {
#        iframe.setAttribute('height', '100vh');
#        iframe.parentElement.style.display = 'flex';
#        iframe.style.minHeight = '1px';
#        iframe.style.display = 'flex';
#      }
#
# }// end of if
#
# }, 800); // end of setTimeout
#
# </script>
# <!-- new oneman logo temp fix -->
# <style>
# .rss-widget__logo_oneman:hover {
#     background-position: 224px -106px!important;
# }
# </style><style>
# /* TEMP FIX */
# .more-news-bestof::after {
#   content: '';
#   display: table;
#   clear: both;
# }
# .more-news-bestof {
#   float: none;
# }
# </style><style>
# /* TEMP FONT FIX FOR CORONAVIRUS WIDGET */
# table#coronavirus-body-block td {
#   font-weight: 800;
# }
# table#coronavirus-body-block td a {
#   font-weight: 700;
# }
# .article-body .teaser.coronavirus-widget .widget-header__title {
#   padding-top: 0!important;
# }
# </style><style>
# /* TEMP CSS FOR LIVE UPDATES [PROD-976] */
# .teaser_liveupdates .carousel-dots {
# bottom: 7px;
# }
# .teaser_liveupdates .carousel-dots button {
# width: 14px;
# height: 14px;
# }
# </style><!-- temp fix for task: [MARK-520] -->
# <script>
# setTimeout( function(){
#     if(document.getElementById("stayHome") !== null){
#         document.getElementById("stayHome").innerHTML = "#ΜένουμεΣπίτι";
#     }
# }, 400);
# </script><style>
# /* TEMP STYLES [PROD-996] */
# @keyframes live-pulse {
#     0% {
#         opacity: 1
#     }
#     10% {
#         opacity: .25
#     }
#     40% {
#         opacity: 1
#     }
#     100% {
#         opacity: 1
#     }
# }
# span.live-tag::before {
#     content:'';
#     display: inline-block;
#     width: 0.73em;
#     height: 0.73em;
#     background: #e20004;
#     border-radius: 0.5em;
#     margin-right: 0.2ch;
#     animation: live-pulse 1s infinite;
# }
# .teaser_liveupdates .widget-header a,
# .teaser_liveupdates .widget-header a:hover {
# color: #fff;
# }
# </style><style>
# /* PROD-1002 */
# .ece_frontpage .d-flex-row,
# .art_20-20 .d-flex-row,
# .good-news  .d-flex-row{
#    display: block;
# }
# .ad-widget_300x250 {
#    padding: 0!important;
# }
# .teaser .article__title a,
# .top-stories .article__title a,
# .news .sidebar .mh_ta_xasete .article__title a {
#   font-family: 'Roboto Slab', sans-serif;
#   font-weight: 800;
#   line-height: 18px;
# }
# .csr_stories  .article__title a {
#   line-height: 1.090909 !important;
# }
# .news .sidebar .mh_ta_xasete .article__title {
#   margin: 6px 0;
#   overflow-y: hidden;
# }
# .teaser_kairos .article .article__title a {
#    line-height: 24px;
# }
# .news .sidebar .teaser:last-of-type:after {
#  border-top: 0;
# }
# .article__supertitle,
# .article__section:hover,
# .teaser .article__supertitle,
# .top-stories .article__supertitle,
# .news-stream__item__tag:focus,
# .news-stream__item__tag:hover {
#   background-color: #1955a5;
# }
# .article__section,
# .teaser.teaser_paixnidia-eksousias_wide .teaser__content .article__supertitle,
# .news-stream__item__tag {
#   color: #1955a5;
# }
# body.ece_frontpage .teaser__big-story .article__title {
#   font-size: 5.2rem;
#   letter-spacing: -.02em;
#   line-height: 1.077;
# }
# .article__section {
#   line-height: 1.5;
# }
# .article__summary {
#   line-height: 1.2858;
# }
# body.ece_frontpage .teaser_topstory-editorial .article .article__title,
# body.ece_frontpage .top-stories__article .article__title {
#   line-height: 1.08333;
#   letter-spacing: -0.02em;
# }
# body.ece_frontpage .teaser_topstory-main .article__title {
#   line-height: 1.07143;
#   letter-spacing: -0.02em;
# }
# .teaser.teaser_paixnidia-eksousias_wide .teaser__content .article__title {
#   line-height: 1.22222;
#   font-weight: 800;
#   letter-spacing: -0.02em;
# }
# .coronavirus-widget::before {
#   background-color: #FDD831;
# }
# .coronavirus-widget .widget-header__title:after,
# .coronavirus-widget .teaser__article .article__supertitle {
#   color: #FDD831;
# }
# .coronavirus-widget .col-md-4 .teaser__article .article__title {
#   line-height: 1.3077;
# }
# .coronavirus-widget .col-md-3 .teaser__article .article__title {
#   font-size: 1.7rem;
#   line-height: 1.17647;
#   max-height: 3.4em;
#   margin: 6px 0!important;
# }
# .widget-header {
#   border-color: #000;
# }
# .teaser.teaser_paixnidia-eksousias_wide .teaser__content .article__title a:hover:before {
#   border-color: #1955a5;
#   background-color: #1955a5;
# }
# body.ece_frontpage .article_top .article__title {
#   line-height: 1.0938;
# }
# .article_binary .article__title.boldest,
# .article_nopicture .article__title.boldest,
# .article_top .article__title.boldest {
#   font-size: 3.2rem;
# }
# .article__title {
#   letter-spacing: -0.02em;
# }
# .rss-widget_homemid .rss-widget__article .article__title {
#   font-family: 'Roboto Slab', sans-serif;
#   font-size: 1.7rem;
#   line-height: 1.17647;
#   letter-spacing: -0.02em;
#   font-weight: 800;
# }
# .news-stream__item__link {
#   font-family: 'Roboto Slab', sans-serif;
#   line-height: 1.3077;
# }
# .teaser_sidebar .teaser__article .article__title {
#   line-height: 1.090909;
#   letter-spacing: -0.02em;
# }
# body.ece_frontpage .huffpost-widget__article .article__title {
#   font-family: 'Roboto Slab', sans-serif;
#   font-weight: 800;
#   line-height: 1.2857;
#   letter-spacing: 0;
# }
#
# /* section */
# .section .teaser_section-page .teaser__article .article__title { margin: 10px 0 8px; }
# .section .teaser_section-page .teaser__article .article__title a { line-height: 22px; }
# .teaser .section_description h2 { letter-spacing: 0px; }
#
# /* Article */
# .art_20-20 #article-ifo, .good-news #article-ifo {float: none; margin: 0 auto; position: unset;}
# .art_20-20 #article-ifo + aside, .good-news #article-ifo + aside { float: none; display: none!important; }
# .d-flex-row .content.start {flex: 1 0 0;}
# #article-ifo .article-head .article-head__article-head-section-name { color: #1955A5;  font-family: 'Roboto Slab', sans-serif; font-size: 16px;}
#
# #article-ifo .article-head .article-head__article-head-section-name:hover { color: #fff; background-color: #1955A5;}
#
# #article-ifo .article-body__tags  a { color: #1955A5!important; font: 700 16px/24px Roboto Slab;text-transform: uppercase;}
# .news .article-body__relcontent { font: 700 16px/24px Roboto Slab; }
#
# #article-ifo .article-body .article-body__article-headline { font-family: 'Roboto Slab', sans-serif; font-weight: 800; color: #000000;font-size: 40px;line-height: 44px; letter-spacing:  -0.8px;}
#
# .news .article-body__body h2 { font: 800 22px/26px Roboto Slab; color: #000000;  letter-spacing: -0.44px;}
#
# table#coronavirus-body-block h2 { letter-spacing: 0; }
# table#coronavirus-body-block { border-bottom: 5px solid #000000!important; width: 100% }
# table#coronavirus-body-block tbody { font: 800 16px/23px Roboto Slab; }
# .more-news-bestof article a { font: 800 16px/18px Roboto Slab; }
# .bestof-widget__title { font: 400 20px/28px Roboto Slab;  text-transform: uppercase;}
# .more-news-bestof article.rss-widget__article.article h2 a { max-height: 56px; }
# .newsletter-form__title { font: 800 28px/28px Roboto Slab; }
# .newsletter-form__button { font: 700 14px/24px Roboto Slab;
# letter-spacing: 0; }
#
# /* Footer  */
# .read-more-widget__title { font: 400 20px/28px Roboto Slab; }
# .rss-widget_simple .rss-widget__article .article__title { font: 800 13px/17px Roboto Slab; }
# .read-more-widget__title:after, .read-more-widget__title:before { width: calc(50% - 110px); top: 15px;}
# </style><style>
# /* TEMP COLOR CHANGES FOR GOOD NEWS WIDGET [PROD-1054] */
# .teaser_tripleCarousel.teaser_good-news-widget {
#   border-color: #00ddaa;
#   padding-bottom: 20px;
# }
# .teaser_tripleCarousel.teaser_good-news-widget .teaser__logo {
#   top: 0;
#   padding: 0 20px;
#   max-width: unset;
# }
# </style><style>
#    .main-menu__menubar a.navmenu__link.internal[title="20-20"] {font-size: 0;}
#    .side-menu__navmenu a.navmenu__link.internal[title="20-20"] { border-bottom: none; font-size: 0;}
#     .main-menu__menubar a.navmenu__link.internal[title="20-20"].navmenu__link_active { border-bottom: none; font-size: 0;}
#    .side-menu__navmenu a.navmenu__link.internal[title="20-20"].navmenu__link_active { border-bottom: none; font-size: 0;}
# </style><style>
#    /* fixing Main Menu mini brands styles */
#    .navmenu_horizontal { float: none; }
#    .navmenu_horizontal .navmenu__item:last-child {padding-right: 0;}
#    .search-field__input {top: 9px;}
#    .main-menu__menubar a.navmenu__link.internal[title="Good News"].navmenu__link_active,
#    .main-menu__menubar a.navmenu__link.internal[title="20-20"].navmenu__link_active,
#     .main-menu__menubar a.navmenu__link.internal[title="Δελτίο Καιρού"].navmenu__link_active
#    {
#         border-bottom: none!important;
#    }
#
#    .side-menu__navmenu a.navmenu__link.internal[title="20-20"].navmenu__link_active,
#    .side-menu__navmenu a.navmenu__link.internal[title="Good News"].navmenu__link_active,
#    .side-menu__navmenu a.navmenu__link.internal[title="Δελτίο Καιρού"].navmenu__link_active {
#       border-bottom: none!important;
#    }
# </style><style>
# .standardTemplateWithoutSidebar:not(.good-news):not(.art_20-20) #article-ifo {
#     float: none;
#     margin: 0 auto;
# }
# </style><!-- tablet bug fix header width 13/11/2020  -->
# <style>
# body > #header {
#     min-width: 1000px;
# }
# </style><style>
# /* release fixes */
# .live-blog.news.standardTemplate > .container{
# margin-top: 85px;
# }
#
# .sec_20-20.section,
# .art_20-20.news.standardTemplate,
# .good-news.section,
# .good-news.news.standardTemplate{
# /*margin-top: 85px;*/
# }
#
# .search-field__input {
#     top: -6px;
# }
#
# body.live-blog.news > .container > aside #live-blog-key-events-container,
# body.live-blog.news.standardTemplate > .container > aside #stuck-ads-container .ads-container,
# body.section:not(.good-news) .grid_ad_good-news{
# top:90px;
# }
#
# body.section:not(.ece_frontpage) .wrapper-sticky--enabled+.teaser_liveupdates {
#     margin-bottom: 0px;
# }
# .navmenu__link_external:after{
#     right: -15px;
# }
# </style><style>
# /* redesign 2020 fix 5ada col-4 */
# .top-stories-5articles .sidebar .top-stories__article {
#   width: 314px!important;
#   max-width: 314px;
# }
# </style><style>
# /* redesign 2020 fix header search */
# .search-field:hover .search-field__button {
#     background: url(/resources/79a99fs/images/menu-spritemap.png) no-repeat -236px 0;
# }
# </style><!-- [ADOPS-6] fix article stuck slots desktop -->
# <style>
# body.news #ros-300x250b,
# body.news .grid_ad_good-news_container-c{
#     top:90px;
# }
# </style><!--
# PROD-1722?focusedCommentId=34299
# -->
# <style>
# .teaser_liveupdates .carousel-dots button{
# background-color: #fff;
# }
# .teaser_liveupdates .carousel-dots button.active{
# background-color: #e10005;
# }
# .lakis-lazopoulos.news #article-ifo .article-body .logo_lakis-lazopoulos .logo {
#     width: 660px ;
#     height: 268px ;
#     background: url(https://www.news247.gr/img/app/9463661/0/o/0/0/Header_Podcast_Desktop.png) no-repeat ;
# }
# .lakis-lazopoulos.news #article-ifo .article-body .logo_lakis-lazopoulos .logo a {
#     width: 100%;
#     height: 100%;
#     display: block;
# }
#
# </style>
#
# <!-- SUP-613 | initialize margin bottom 40px class for pollitics widgets */ -->
# <style>
# body .pollitics-widgets-margin-bottom--40{
# margin-bottom:40px!important;
# }
# </style><!-- TECH-207 -->
# <style>
# .huffpost-widget__article .article__title{
#     letter-spacing: -.42px!important;
# }
#
# /* Good new Article  fix center Facebook embed */
# .good-news.news #article-ifo .article-body__storyContent .article-body__body__inline.article-body__body__inline--intrinsic{
# text-align:center;
# }
# </style>
# <style>
#     header.header section.teaser_liveupdates {
#         margin: 0 0 10px;
#     }
#
# figure.thirdparty_custom--desktop {
#     margin-bottom: 30px;
# }
#
# .navmenu__link_external:after {
# right: unset;
# left: calc(100% + 5px);
# }
# </style>
#
# <style>
# .teaser--1821-sidebar .widget-header {
#     border-color: #3D7BAF;
# }
# .teaser--1821-sidebar .widget-header__title {
#     font-size: 0;
#     background: url(/img/app/9233874/0/o/0/0/181_widget_header_sidebar.png) center/contain no-repeat;
#     width: 100%;
#     height:190px;
#     margin-top: 20px;
# }
# </style>
#
# <!-- fix for task SUP-63 | start -->
# <style>
# body.news [id^='adman-inpage-video-'] a,
# body.news [id^='adman-inpage-video-'] a:hover,
# body.news [id^='adman-inpage-video-'] .vast-blocker,
# body.news [id^='adman-inpage-video-'] .vast-blocker:hover{
# 	color:unset;
# 	background-color:unset;
# }
# </style>
# <!-- fix for task SUP-63 | end -->
#
# <!-- ADOPS-89 | main-content changed display to flex so ad hp-300x250j sticky to work  -->
# <style>
# .ece_frontpage div#main-content{
# display:flex;
# }
# </style>
#
# <!-- SUP-539 temp fix -->
# <style>
# @media (max-width:1023px){
# 	body:not(.mobile) [id*=hp-970x250a]:not([id*=google_ads_iframe_]), body:not(.mobile) [id*=ros-970x250a]:not([id*=google_ads_iframe_]){
# 		display:none!important;
# 	}
#
#         body:not(.mobile) [id*=ros-300x250a]:not([id*=google_ads_iframe_]){
#                  height:250px;
# }
#         body:not(.mobile) .adSlot-height--premium {
#     height: unset;
# }
# }
#
# .ceros-fasa{
# margin-bottom:40px;
# }
#
#
# /* Εκλογες 2023 temp change 20-05-2023*/
# .row.d-flex-row.main-content.redesign2020-triple-column.ekloges-2022-body{display:none!important;}
# section.teaser.teaser__big-story_plain.escenic-no-lazy {
#     margin-top: 30px;
# }
# </style>
# <style>
# body.videos .ekloges2023-overlay_player_widget{display:none;}
# </style><!--  TECH-195 -->
# <script>
# document.addEventListener("click", function(e){
#     //console.info('e.target: ',e.target);
#     var elem = e.target;
#     var elem_classList = elem.classList;
#
#     switch(true){
#         case elem_classList.contains('main-menu__toggle'):
#         window.dataLayer.push({'event': 'Burger Menu Clicked Side Menu is Open'});
#         //console.info("Burger Menu Clicked Side Menu is Open");
#         break;
#         case elem_classList.contains('side-menu__close'):
#         case elem_classList.contains('side-menu__backdrop'):
#         window.dataLayer.push({'event': 'Close Button Clicked Side Menu is Closed'});
#         //console.info("Close Button Clicked Side Menu is Closed");
#         break;
#         case elem_classList.contains('navmenu__link'):
#         if(elem.parentElement.parentElement.classList.contains("navmenu_vertical"))
#             window.dataLayer.push({'event': 'Sidebar Menu Clicked Side Menu is Closed'});
#             //console.info("Sidebar Menu Clicked Side Menu is Closed");
#         break;
#         default:
#         //console.info("do nothing");
#     }
#
# }, false);
#
# // track escape
# document.addEventListener("keydown", function(evt) {
#     evt = evt || window.event;
#     var isEscape = false;
#     var _sideMenuDisplay = document.querySelector("#side-menu__backdrop").style.display;
#     if ("key" in evt) {
#         isEscape = (evt.key === "Escape" || evt.key === "Esc");
#     } else {
#         isEscape = (evt.keyCode === 27);
#     }
#     if (isEscape && _sideMenuDisplay == "block") {
#         //console.info("Escape");
#         window.dataLayer.push({'event': 'Close Button Clicked Side Menu is Closed'});
#     }
# });
#
# /* remove when [TECH-205] released */
# window.addEventListener('DOMContentLoaded', (event) => {
#
# document.querySelectorAll(".social-links__icon_fb")[0].setAttribute('data-gtm', 'social links header facebook');
# document.querySelectorAll(".social-links__icon_fb")[1].setAttribute('data-gtm', 'social links side menu facebook');
#
# document.querySelectorAll(".social-links__icon_tw")[0].setAttribute('data-gtm', 'social links header twitter');
# document.querySelectorAll(".social-links__icon_tw")[1].setAttribute('data-gtm', 'social links side menu twitter');
#
# document.querySelectorAll(".social-links__icon_insta")[0].setAttribute('data-gtm', 'social links header instagram');
# document.querySelectorAll(".social-links__icon_insta")[1].setAttribute('data-gtm', 'social links side menu instagram');
#
# });
#
# </script></head>
#             <body id="ece_frontpage" class="latest section" >
#                         <!-- Google Tag Manager (noscript) -->
#                     <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PPWK62G" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#                     <!-- End Google Tag Manager (noscript) -->
#                 <script>
#                     (function(w, d){
#                         var b = d.getElementsByTagName('body')[0];
#                         var s = d.createElement("script");
#                         var v = !("IntersectionObserver" in w) ? "8.17.0" : "10.19.0";
#                         s.async = true; // This includes the script as async. See the "recipes" section for more information about async loading of LazyLoad.
#                         s.src = "https://cdn.jsdelivr.net/npm/vanilla-lazyload@" + v + "/dist/lazyload.min.js";
#                         w.lazyLoadOptions = {elements_selector: ".lazy"};
#                         b.appendChild(s);
#                     }(window, document));
#                 </script>
#
#                 <!-- HEADER -->
#                 <header class="header" id="header">
#                             <div  class="code-widget adSlot-height--premium">
#     <!-- /4834629/news247.gr/'ros-970x250a -->
# <div class="premium_banner_wrapper parent" >
# <div id='ros-970x250a'  class="premium_banner child" >
#
#
#
# </div>
# </div>
#
# <style>
# /*google_ads_iframe_/4834629/news247.gr/ros_970x250a_0__container__*/
# .isPremium [id="google_ads_iframe_/4834629/news247.gr/hp_970x250a_0__container__"],
# .isPremium [id="google_ads_iframe_/4834629/news247.gr/ros_970x250a_0__container__"]{
#     position: absolute;
# }
# body.tablet, html.tablet{
# width:100vw;
# }
# body.tablet .premium_banner_wrapper.parent{
# display: contents;
# }
# </style></div>
#
# <div class="content start wrapper-sticky" >
#             <div  class="code-widget ">
#     <script>
#     var url_string = window.location.href;
#     var url = new URL(url_string);
#     var _preview = url.searchParams.get("preview") ? true : false;
#     var _preview = true;
#
#     var _premium_isOpen = false;
#     var _premiun_parent;
#     var _premiun_parent_height;
#     var _wrapper_sticky_elem;
#     var _trigger_point = 200;
#
#     var _isHome = document.body.classList.contains("ece_frontpage") || document.body.classList.value.indexOf("ece_frontpage") > -1;
#
#     var _hasLiveUpdatesTeaser = false;
#     var _hasAdblock = (typeof googletag.pubads !== "function") ? true : false;
#     var dontShow3rdParty = document.body.classList.contains("dontShow3rdParty") ? true : false;
#
#
#
#     function initStuckAndAnimation() {
#
#         _premiun_parent = document.querySelector(".premium_banner_wrapper");
#
#         //_premiun_parent_height = _isHome ? _premiun_parent.getBoundingClientRect().height : 0;
#         //_premiun_parent_height = _premiun_parent.getBoundingClientRect().height ;// new
#         _premiun_parent_height = dontShow3rdParty ? 0 : _premiun_parent.getBoundingClientRect().height;// SUP-338 05/04/2022
#
#         _premium_isOpen = _premiun_parent_height > 1 ? true : false;
#
#         _hasLiveUpdatesTeaser = !!document.querySelector('#header .teaser_liveupdates');
#
#         last_known_scroll_position = window.scrollY;
#         _trigger_point = _premiun_parent_height + _trigger_point;
#         _wrapper_sticky_elem = document.querySelector(".wrapper-sticky");
#
#         if (last_known_scroll_position > _premiun_parent_height ) {
#             _wrapper_sticky_elem.classList.add("wrapper-sticky--enabled");
#         }
#
#         //if (last_known_scroll_position >= _trigger_point && _isHome) {
#         if (last_known_scroll_position >= _trigger_point ) { //new
#             document.querySelector(".main-menu__container-top").classList.add("header--small");
#             document.querySelector(".main-menu__container-top").classList.remove("header--big");
#         }
#
#         window.addEventListener('scroll', function(e) {
#             last_known_scroll_position = window.scrollY;
#
#             //console.info("last_known_scroll_position : ", last_known_scroll_position);
#             //console.info("_premiun_parent_height : ", _premiun_parent_height);
#             //console.info("_premium_isOpen : " , _premium_isOpen);
#             //console.info("_preview : " , _preview);
#             //console.info("_wrapper_sticky_elem : " , _wrapper_sticky_elem);
#
#             var _canScaleUp = document.querySelector(".main-menu__container-top").classList.contains("header--big") ? true : false;
#             var _canScaleDown = document.querySelector(".main-menu__container-top").classList.contains("header--small") ? true : false;
#
#             if (last_known_scroll_position >= _premiun_parent_height ) {
#
# //console.info("last_known_scroll_position", last_known_scroll_position);
# //console.info("_premiun_parent_height", _premiun_parent_height);
#
# if(_wrapper_sticky_elem !== null){
#                 _wrapper_sticky_elem.classList.add("wrapper-sticky--enabled");
# }
#
#                 // if teaser liveupdates is missing from header (not on homepage)
#                 if (!_isHome && !_hasLiveUpdatesTeaser) {
#                     document.querySelector("body > .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("good-news news") > -1) {
# console.info("good-news news");
#                     document.querySelector(".good-news.news.standardTemplate .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("good-news section") > -1) {
# console.info("good-news section");
#                     document.querySelector(".good-news.section .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("sunday-edition news") > -1) {
#                     document.querySelector(".sunday-edition.news .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("sunday-edition section") > -1) {
#                     document.querySelector(".sunday-edition.section .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("art_20-20 news") > -1) {
# console.info("art_20-20 news");
#                     document.querySelector(".art_20-20.news .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("sec_20-20 section") > -1) {
# console.info("sec_20-20 section");
#                     document.querySelector(".sec_20-20.section .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("sustainability section") > -1) {
# console.info("sustainability section");
#                     document.querySelector(".sustainability.section .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("sustainability news") > -1) {
# console.info("sustainability news");
#                     document.querySelector(".sustainability.news .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("afieroma-ygeia-kai-prolipsi news") > -1) {
# console.info("sustainability news");
#                     document.querySelector(".afieroma-ygeia-kai-prolipsi.news .container").classList.add("marginTop95");
#                 }
#
#                 if (document.body.classList.value.indexOf("afieroma-ygeia-kai-prolipsi section") > -1) {
# console.info("sustainability section");
#                     document.querySelector(".afieroma-ygeia-kai-prolipsi.section .container").classList.add("marginTop95");
#                 }
#
#
#                 if (document.body.classList.value.indexOf("ekthesi-pissaridi tag") > -1) {
# console.info("ekthesi-pissaridi tag");
#                     document.querySelector(".ekthesi-pissaridi.tag .container").classList.add("marginTop95");
#                 }
#
# /* enable when kinal page goes live */
# if (document.body.classList.value.indexOf("ekloges-kinal tag") > -1) {
# console.info("ekloges-kinal tag");
#                     document.querySelector(".ekloges-kinal.tag .container").classList.add("marginTop95");
#                 }
#
#
#             } else {
#                 document.querySelector(".container").classList.remove("marginTop95");
#
# // fix for lakis article 16-12-2021
# if(_wrapper_sticky_elem){
#                 _wrapper_sticky_elem.classList.remove("wrapper-sticky--enabled");
# }
#
#             }
#
#             if (last_known_scroll_position > _trigger_point && _isHome) {
#                 document.querySelector(".main-menu__container-top").classList.add("header--small");
#                 document.querySelector(".main-menu__container-top").classList.remove("header--big");
#             } else if (last_known_scroll_position < _trigger_point && _canScaleDown) {
#                 document.querySelector(".main-menu__container-top").classList.add("header--big");
#                 document.querySelector(".main-menu__container-top").classList.remove("header--small");
#             }
#
#         }); // end of event scroll
#
#     } //end of function initStuckAndAnimation();
#
#     // Section & Article stuck
#
#
# window.addEventListener('DOMContentLoaded', (event) => {
#
#         if (!_isHome) {
#             initStuckAndAnimation();
#         } else if (_isHome && _hasAdblock) {
#             initStuckAndAnimation();
#         }
#
#     });
#
# </script>
#
# <style>
#
# body.author>.container, body.section:not(.ece_frontpage)>.container, body.tag>.container {
#     padding-top: 10px;
# }
#     /* fix for section liveupdates */
#
#     body:not(.ece_frontpage) .container.marginTop95,
#     body:not(.ece_frontpage) .wrapper-sticky--enabled+.teaser_liveupdates {
# margin-top: 85px!important;
#     }
#
#
#     body.ece_frontpage .wrapper-sticky--enabled+.teaser_liveupdates {
#         margin-top: 110px;
# margin-top: 130px;
#     }
#
#     /*
#     new top value for sticky banners
#     for 20-20 & good-news sections
#     */
#
#     .section.good-news .grid_ad_good-news,
#     .section.good-news .grid_ad_good-news_container,
#     .section.sec_20-20 .grid_ad_in_sticky_container-b {
#         top: 95px;
#     }
#
#
#     .search-field:hover .search-field__button {
#         background-position: -236px 0;
#     }
#
# </style>
#
# <style>
# /*
#     body:not(.ece_frontpage) .container.marginTop95,
#     body:not(.ece_frontpage) .wrapper-sticky--enabled+.teaser_liveupdates {
#         margin-top: 75px!important;
#     }
# */
#
# body.sunday-edition.section .container.marginTop95{
# margin-top: 100px!important;
# }
#
#     .sec_20-20.section .container,
#     .good-news.section .container,
#     .good-news.news.standardTemplate .container,
#     .art_20-20.news.standardTemplate .container,
#     .sustainability.news.standardTemplate .container{
#         padding-top: 0px!important;
#     }
# </style></div>
#
# <div class="main-menu main-menu-2020">
#     <div class="main-menu__container">
#
#         <!-- Menu top -->
#         <div class="main-menu__container-top ">
#             <div class="main-menu__container-top--left">
#                 <i class="main-menu__toggle" onclick="openNav();" role="button" aria-hidden="true"></i>
#                 <div class="main-menu__logo logo ">
#                     <a href="https://www.news247.gr/" class="logo__link" title="News 24/7">
# ...
# 				</a>
# 			</div>
# 		</div>
#
# 	</div>
#  <div id="contactFormContainer" class="contactFormContainer modal fade in" role="dialog">
#     <div class="modal-dialog">
#         <!-- Modal content-->
#         <div class="modal-content">
#             <div class="modal-header">
#                 <h2 class="generic_header contact_header" >Επικοινωνία</h2>
#                 <button type="button" class="close" onclick="closeContact();"  data-dismiss="modal">×</button>
#             </div>
#             <div class="modal-body">
#                 <form id="contact-form" name="contact-form-4681831" class="contactForm" action="#" method="POST" novalidate="novalidate">
#
#                     <div class="form-group col-md-6">
#                         <label for="subj">Προς *</label>
#                         <select name="subj" class="form-control" id="subj">
#
#                             <option value="epikoinwnia" selected>ΕΠΙΚΟΙΝΩΝΙΑ</option>
#                                     <option value="diafhmistiko-tmhma">ΔIAΦΗΜΙΣΗ</option>
#                                 </select>
#                         <!--input type="hidden" name="subj" value="epikoinwnia" class="text ui-widget-content ui-corner-all"
#                         <input type="hidden" name="address" class="text ui-widget-content ui-corner-all">
#                         <input type="hidden" name="tel" class="text ui-widget-content ui-corner-all">-->
#                     </div>
#                     <div class="clearfix"></div>
#                     <div class="form-group col-md-6 form_name">
#                         <label for="name">Όνομα *</label>
#                         <input type="text" class="form-control" name="name" id="name">
#                         <div class="errorForm"></div>
#                     </div>
#                     <div class="form-group col-md-6 mail_form">
#                         <label for="mailFrom">Email *</label>
#                         <input type="text" class="form-control" name="mailFrom" id="mailFrom">
#                         <div class="errorForm"></div>
#                     </div>
#                     <div class="form-group col-md-6 adr_form">
#                             <label for="adrFrom">ΔΙΕΥΘΥΝΣΗ *</label>
#                             <input type="text" class="form-control" name="adrFrom" id="adrFrom">
#                             <div class="errorForm"></div>
#                         </div>
#                         <div class="form-group col-md-6 tel_form">
#                             <label for="telFrom">ΤΗΛΕΦΩΝΟ</label>
#                             <input type="text" class="form-control" name="telFrom" id="telFrom">
#                             <div class="errorForm"></div>
#                         </div>
#                     <div class="form-group col-md-12 message_form">
#                         <label for="plainContent">Μήνυμα *</label>
#                         <textarea class="form-control" name="plainContent" id="plainContent"></textarea>
#                         <div class="errorForm"></div>
#                     </div>
#                     <div class="col-md-6 placehold">
#                         <div class="contactFormMessage viablePlaceholder"></div>
#                     </div>
#                     <div class="form-group col-md-6" style="float:right;">
#                         <button id="btn" class="btn btn-primary" type="button">ΑΠΟΣΤΟΛΗ</button>
#                     </div>
#
#                     <div class="form-group col-md-12">
#                         <label>* Υποχρεωτικά Πεδία</label>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </div>
# <script>
#
#     function openContact() {
#         $(".modal-backdrop").show();
#         $("body").prepend("<div class='modal-backdrop'></div>");
#         $("body").addClass(" openModal");
#         $(".modal").css('display', 'block');
#         $("div#contactFormContainer .modal-content").slideDown();
#     }
#     function closeContact() {
#         $(".modal-backdrop").remove();
#         $("body").removeClass(" openModal");
#         $("body").removeClass(" stayBottom");
#         $("div#contactFormContainer .modal-content").slideToggle();
#         $(".modal").delay(6000).hide();
#     }
#
#     function openContactMobile() {
#         //$("nav.radiofono-menu__wraper").addClass("hidden");
#         $(".modal-backdrop").show();
#         $("body").prepend("<div class='modal-backdrop'></div>");
#         $("body").addClass(" openModal");
#         $(".modal").css('display', 'block');
#         $("div#contactFormContainer .modal-content").slideDown();
#         var height = $(window).height();
#         $('.modal-content').css('height', height - 100);
#     }
#     function openBottomContactNormal() {
#         $(".modal-backdrop").show();
#         $("body").prepend("<div class='modal-backdrop'></div>");
#         $("body").addClass(" openModal");
#         $("body").addClass(" stayBottom");
#         $(".modal").css('display', 'block');
#         $("div#contactFormContainer .modal-content").slideDown();
#     }
#     function openBottomContact() {
#         $(".modal-backdrop").show();
#         $("body#radiofono247").prepend("<div class='modal-backdrop'></div>");
#         $("body#radiofono247").addClass(" openModal");
#         $("body#radiofono247").addClass(" stayBottom");
#         $("body.radiofono247").prepend("<div class='modal-backdrop'></div>");
#         $("body.radiofono247").addClass(" openModal");
#         $("body.radiofono247").addClass(" stayBottom");
#         $(".modal").css('display', 'block');
#         $("div#contactFormContainer .modal-content").slideDown();
#     }
#     $(document).ready(function () {
#         //name?mailFrom?adrFrom?telFrom?plainContent
#         $("#btn").click(function () {
#             $(".contactFormMessage").html('');
#             var name = $("input#name").val();
#             var mailFrom = $("input#mailFrom").val();
#             var adrFrom = $("#adrFrom").val();
#             var telFrom = $("#telFrom").val();
#             var subjFrom = $("#subj option:selected").text();
#             var plainContent = $("#plainContent").val();
#             var dataString = 'name=' + name + '&mailFrom=' + mailFrom + '&plainContent=' + plainContent + '&adrFrom=' + adrFrom + '&telFrom=' + telFrom + '&subj=' + subjFrom;
#             if (name == '' && mailFrom == '' && plainContent == '' && adrFrom == '') {
#                 $(".form_name .errorForm").html('Παρακαλώ συμπληρώστε το όνομα σας');
#                 $("input#name").css('border-color', 'red');
#                 $(".mail_form .errorForm").html('Παρακαλώ συμπληρώστε το email σας');
#                 $("input#mailFrom").css('border-color', 'red');
#                 $(".message_form .errorForm").html('Παρακαλώ συμπληρώστε το μήνυμα σας');
#                 $("#plainContent").css('border-color', 'red');
#                 //$(".tel_form .errorForm").html('Παρακαλώ συμπληρώστε το τηλέφωνο σας');
#                 //$("#telFrom").css('border-color', 'red');
#                 $(".adr_form .errorForm").html('Παρακαλώ συμπληρώστε τη διεύθυνση σας');
#                 $("#adrFrom").css('border-color', 'red');
#             } else if (name == '') {
#                 $(".form_name .errorForm").html('Παρακαλώ συμπληρώστε το όνομα σας');
#                 $("input#name").css('border-color', 'red');
#             } else if (mailFrom == '') {
#                 $(".mail_form .errorForm").html('Παρακαλώ συμπληρώστε το email σας');
#                 $("input#mailFrom").css('border-color', 'red');
#             } else if (adrFrom == '') {
#                 $(".adr_form .errorForm").html('Παρακαλώ συμπληρώστε τη διεύθυνση σας');
#                 $("#adrFrom").css('border-color', 'red');
#             //} else if (telFrom == '') {
#                 //$(".tel_form .errorForm").html('Παρακαλώ συμπληρώστε το τηλέφωνο σας');
#                 //$("#telFrom").css('border-color', 'red');
#             } else if (plainContent == '') {
#                 $(".message_form .errorForm").html('Παρακαλώ συμπληρώστε το μήνυμα σας');
#                 $("input#plainContent").css('border-color', 'red');
#             } else if (name != '' && mailFrom != '' && plainContent != '' && adrFrom != '') {
#                 $(".contactFormMessage.viablePlaceholder").addClass('loading-form');
#                 $("button#btn").addClass('disable_button');
#                 $(".placehold").addClass('disable_cursor');
#                 $.ajax({
#                     type: "POST",
#                     url: "https://www.news247.gr/widget/id6125158?view=ajax",
#                     data: dataString,
#                     success: function (data) {
#                         console.log(data);
#                         $("button#btn").removeClass('disable_button');
#                         $(".contactFormMessage.viablePlaceholder").removeClass('loading-form');
#                         $(".placehold").removeClass('disable_cursor');
#                         $(".contactFormMessage").html('Στάλθηκε επιτυχώς');
#                         $("input:text").val("");
#                         $("textarea").val("");
#                     }
#                 });
#             } else {
#                 $(".contactFormMessage").html('Παρακαλώ συμπληρώστε τα πεδία');
#             }
#             $("#contactFormContainer form :input").each(function () {
#                 var input = $(this).not('#telFrom').val();
#                 if (input !== '') {
#                     $(this).css('border-color', '#cccccc');
#                 } else {
#                     $(this).css('border-color', 'red');
#                 }
#             });
#         });
#     });
#
#
# </script>
# <style>
# .loading-form {
#     width: 35px;
#     height: 35px;
#     background-size: cover;
#     background-image: url(https://www.news247.gr/resources/b609df7/images/loading-2.gif);
# }
# .disable_button {
#     background: #bfbfbf!important;
#     cursor: not-allowed;
#     pointer-events: none;
# }
# .placehold.disable_cursor{
#     cursor: not-allowed;
# }
# </style></footer>
#                     <script src="https://www.news247.gr/resources/b609df7/scripts/main-desktop.js"></script>
#         <script>
#     $('#csr_stories').find('a').attr('target','_blank');
#     $('#csr_stories').find('a').css('display', 'block');
# </script><style>
# body:not(.mobile) [id^=hp]:not([id*=google_ads_iframe_]),
# body:not(.mobile) [id^=ros]:not([id*=google_ads_iframe_]),
# body:not(.mobile) [id^=div-gpt-ad-]:not([id*=google_ads_iframe_]),
# body:not(.mobile) [id^=sunday_]:not([id*=google_ads_iframe_]){
#     display:flex;
#     justify-content: center;
#     flex-direction: column;
# }
#
# body.mobile [id^=sunday_]:not([id*=google_ads_iframe_]){
#     width: auto;
# }
#
# </style><style>
# .premium_banner_wrapper.parent {
#   text-align:center;
#   position: absolute;
#   width: 100%;
#   height: inherit;
#   clip: rect(0, auto, auto, 0);
# }
# </style><script>
#   function setCookie(cname, cvalue, exdays) {
#     const d = new Date();
#     d.setTime(d.getTime() + (exdays * 24 * 60 * 60 * 1000));
#     let expires = "expires="+d.toUTCString();
#     document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";
#   }
#
#   function checkCookie(name, value) {
#     const cookies = document.cookie.split(';');
#     for (let i = 0; i < cookies.length; i++) {
#       const cookie = cookies[i].trim();
#       if (cookie.startsWith(name + '=') && cookie.slice(name.length + 1) === value) {
#         return true;
#       }
#     }
#     return false;
#   }
#
#   // 1. This code loads the IFrame Player API code asynchronously.
#
#   var tag_10037500 = document.createElement("script");
#
#     tag_10037500.src = "https://www.youtube.com/iframe_api";
#
#   var firstScriptTag_10037500 = document.getElementsByTagName("script")[0];
#   firstScriptTag_10037500.parentNode.insertBefore(tag_10037500, firstScriptTag_10037500);
#
#   window.addEventListener("DOMContentLoaded",()=>{
#
#       //Create wrapper element and append it to body
#
#       var overlayPlayerWidget = document.createElement("div");
#       overlayPlayerWidget.setAttribute("class","ekloges2023-overlay_player_widget");
#       document.body.appendChild(overlayPlayerWidget);
#       var overlayHeader = document.createElement("div");
#       overlayHeader.setAttribute("class","overlay_video_header");
#       overlayPlayerWidget.appendChild(overlayHeader);
#
#       // check if __Player cookie exists
#
#       if (checkCookie('__Player', 'max') || checkCookie('__Player', 'min')) {
#           if(checkCookie('__Player', 'min')){
#             overlayHeader.classList.add("active");
#           }else{
#             overlayHeader.classList.remove("active");
#           }
#       } else {
#           setCookie('__Player', 'max', 1)
#       }
#
#       //Create rest elements
#
#       var overlayPlayerImages = document.createElement("div");
#       overlayPlayerImages.setAttribute("class","overlay_video_header--images");
#       overlayHeader.appendChild(overlayPlayerImages);
#       var overlayImg1 = document.createElement("img");
#       overlayImg1.setAttribute("src","https://www.news247.gr/resources/b609df7/images/live-ekpompi-2023-desktop.svg");
#       overlayImg1.setAttribute("width","456");
#       overlayImg1.setAttribute("height","33");
#       overlayImg1.setAttribute("alt","LIVE ΕΚΠΟΜΠΗ ΕΚΛΟΓΕΣ 2023");
#       overlayImg1.setAttribute("title","LIVE ΕΚΠΟΜΠΗ ΕΚΛΟΓΕΣ 2023");
#       overlayPlayerImages.appendChild(overlayImg1);
#       var overlayImg2 = document.createElement("img");
#       overlayImg2.setAttribute("src","https://www.news247.gr/resources/b609df7/images/live-ekpompi-2023-desktop-small.svg");
#       overlayImg2.setAttribute("width","230");
#       overlayImg2.setAttribute("height","73");
#       overlayImg2.setAttribute("alt","LIVE ΕΚΠΟΜΠΗ ΕΚΛΟΓΕΣ 2023");
#       overlayImg2.setAttribute("title","LIVE ΕΚΠΟΜΠΗ ΕΚΛΟΓΕΣ 2023");
#       overlayPlayerImages.appendChild(overlayImg2);
#       var overlayPlayerButtonContainer = document.createElement("div");
#       overlayPlayerButtonContainer.setAttribute("class", "overlay_video_header--button");
#       overlayHeader.appendChild(overlayPlayerButtonContainer);
#       var overlayPlayerButton_10037500 = document.createElement("button");
#       overlayPlayerButton_10037500.setAttribute("type","button");
#       overlayPlayerButton_10037500.setAttribute("id","overlayButton_10037500");
#       overlayPlayerButton_10037500.onclick = overlayButtonClicked;
#       overlayPlayerButtonContainer.appendChild(overlayPlayerButton_10037500);
#       var overlayPlayerPlaceholder = document.createElement("div");
#       overlayPlayerPlaceholder.setAttribute("id","10037500");
#       overlayPlayerPlaceholder.setAttribute("class","player-ekloges2023 ");
#       overlayHeader.appendChild(overlayPlayerPlaceholder);
#
#
#       // 2. This function creates an <iframe> (and YouTube player)
#       //    after the API code downloads.
#       var player_10037500;
#
#         window.onYouTubeIframeAPIReady = () => {
#           player_10037500 = new YT.Player("10037500", {
#               height: "325",
#               width: "580",
#               videoId: "NheKIcXpbro",
#               playerVars: {
#                 'autoplay': 1
#               },
#               events: {
#                 'onReady': onPlayerReady,
#               },
#             });
#         }
#         function onPlayerReady(event) {
#           event.target.playVideo();
#           event.target.mute();
#         }
#
#
#       // Collapse/expand when button is clicked and set cookie status
#       function overlayButtonClicked(e) {
#         if (checkCookie('__Player', 'max')) {
#           setCookie('__Player', 'min', 1)
#         } else {
#           setCookie('__Player', 'max', 1)
#         }
#         e.target.parentElement.parentElement.classList.toggle("active");
#       }
#   });
#
# </script>
# <script>
#                     </script>
#                 <script defer src="https://static.cloudflareinsights.com/beacon.min.js/v52afc6f149f6479b8c77fa569edb01181681764108816" integrity="sha512-jGCTpDpBAYDGNYR5ztKt4BQPGef1P0giN6ZGVUi835kFF88FOmmn8jBQWNgrNd8g/Yu421NdgWhwQoaOPFflDw==" data-cf-beacon='{"rayId":"7cae270aae340a61","version":"2023.4.0","b":1,"token":"763f6e3f0def41e3aeeb2bc3949500ec","si":100}' crossorigin="anonymous"></script>
# </body>
#         </html>

# %%
from bs4
import BeautifulSoup 
import requests
site_url="https://www.news247.gr/latest/"
result= requests.get(site_url).text
doc= BeautifulSoup(result, "html.parser")
print(doc.prettify())
# Out:
#   File "<ipython-input-25-c38240c0c344>", line 1
#     from bs4
#             ^
# SyntaxError: invalid syntax

# %%
# define site url
site_url = "https://www.news247.gr/latest/?page=1:6"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feed

# %%
article = Article(urlsL[0])
article.download()
article.parse()

# %%
article.title
# Out:
# 'Exit Poll: Πρωτιά της ΝΔ με μεγάλη διαφορά - Ανεβασμένα ΠΑΣΟΚ και ΚΚΕ'

# %%
# εισάγουμε τις βιβλιοθήκες
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import re
def extract_date(url):
        return re.findall(r'/(\d{4})/(\d{1,2})/(\d{1,2})/', url)
url1= "https://www.news247.gr/latest/2023/05/14"

# %%
articlesL = []
for url in urlsL[:'2023/5/14']:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-913d6af010d5> in <cell line: 2>()
#       1 articlesL = []
# ----> 2 for url in urlsL[:'2023/5/14']:
#       3   articleD = {}
#       4   article = Article(url)
#       5   article.download()
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
import re
def extract_date(url):
        return re.findall(r'/(\d{4})/(\d{1,2})/(\d{1,2})/', url)
url1= "https://www.news247.gr/latest/2023/05/14"

# %%
# define site url
site_url = "https://www.youtube.com/watch?v=L48Me-pes0A"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.youtube.com/rss

# %%
article.title
# Out:
# ''
